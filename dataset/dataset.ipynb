# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import os
import sys
import torch


from google.colab import drive
from google.colab.patches import cv2_imshow

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
img = cv2.imread( "/content/drive/MyDrive/Ai_Lab/data/coco/pic/000000004395.jpg")
plt.imshow(img[...,::-1])

# %%
def segment_draw(img_path:str, segment_point):
  '''
draw the segment on the image
img_path: path to the image
segment_point: list of points to draw the segment [[]]
  '''
  img = cv2.imread( img_path)
  # segment Coordinates
  segmentation = segment_point
  points = np.array(segmentation, np.int32).reshape((-1, 1, 2))
  #Draw a line around the area.
  cv2.polylines(img, [points], isClosed=True, color=(0, 255, 0), thickness=2)
  return img

####Example
img_path =  "/content/drive/MyDrive/Ai_Lab/data/coco/pic/000000007281.jpg"
segment_point = [[473.01,194.0,467.63,181.33,467.25,172.89,465.33,166.75,466.1,161.38,472.24,158.31,474.16,154.86,474.16,151.02,472.62,148.33,469.17,144.11,467.63,137.2,465.33,129.91,468.79,123.39,474.54,122.24,479.91,124.16,481.83,130.68,483.75,138.74,488.36,140.27,494.11,139.51,497.18,139.89,500.25,136.82,494.88,134.52,492.96,131.45,492.58,125.69,496.8,124.16,498.72,126.46,502.17,128.76,514.83,136.82,511.38,142.58,506.01,148.33,517.14,162.92,522.12,171.36,527.5,189.78,522.12,195.92,515.98,194.0,506.01,190.54,503.71,189.39,497.95,182.1,493.73,181.33,489.12,185.17,481.83,189.39,479.53,191.31,476.08,193.23]]
aa = segment_draw(img_path, segment_point)
plt.imshow(aa[...,::-1])

# %%
def bbox_draw(img_path:str, bbox_point):
  '''
draw the bbox on the image
img_path: path to the image
segment_point: list of points to draw the bbox []
  '''
  img = cv2.imread( img_path)
  # Coordinates
  bbox =bbox_point
  # Coordinates of the corners of the rectangle
  x, y, w, h = bbox
  x1, y1 = int(x), int(y)
  x2, y2 = int(x+w), int(y+h)
  # Draw a rectangle on the image
  cv2.rectangle(img, (x1, y1), (x2, y2), (0, 255, 0), 2)
  return img

####Example
img_path =  "/content/drive/MyDrive/Ai_Lab/data/coco/pic/000000007281.jpg"
bbox_point = [465.33,122.24,62.17,73.68]
aa = bbox_draw(img_path, bbox_point)
plt.imshow(aa[...,::-1])
